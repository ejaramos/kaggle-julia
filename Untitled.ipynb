# %%
using Images
using DataFrames

img = imread(nameFile)
# Out:
# WARNING: New definition
#     -(DataArrays.DataArray, AbstractArray) at /Users/ejaramos/.julia/v0.4/DataArrays/src/operators.jl:326
# is ambiguous with:
#     -(AbstractArray, Images.AbstractImageDirect) at /Users/ejaramos/.julia/v0.4/Images/src/algorithms.jl:37.
# To fix, define
#     -(DataArrays.DataArray, Images.AbstractImageDirect)
# before the new definition.
# WARNING: New definition
#     -(AbstractArray, DataArrays.DataArray) at /Users/ejaramos/.julia/v0.4/DataArrays/src/operators.jl:326
# is ambiguous with:
#     -(Images.AbstractImageDirect, AbstractArray) at /Users/ejaramos/.julia/v0.4/Images/src/algorithms.jl:35.
# To fix, define
#     -(Images.AbstractImageDirect, DataArrays.DataArray)
# before the new definition.
# WARNING: New definition
#     -(DataArrays.AbstractDataArray, AbstractArray) at /Users/ejaramos/.julia/v0.4/DataArrays/src/operators.jl:349
# is ambiguous with:
# ...

# %%
using PyPlot

n = 50
srand(1)
x = rand(n)
y = rand(n)
area = pi .* (15 .* rand(n)).^2 # 0 to 15 point radiuses
scatter(x, y, s=area, alpha=0.5)
# Out:
# INFO: Precompiling module PyPlot...
# INFO: Recompiling stale cache file /Users/ejaramos/.julia/lib/v0.4/PyCall.ji for module PyCall.
# INFO: Recompiling stale cache file /Users/ejaramos/.julia/lib/v0.4/PyPlot.ji for module PyPlot.
# WARNING: using PyPlot.imread in module Main conflicts with an existing identifier.
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31edf92d0>)
# PyObject <matplotlib.collections.PathCollection object at 0x31eeea350>
